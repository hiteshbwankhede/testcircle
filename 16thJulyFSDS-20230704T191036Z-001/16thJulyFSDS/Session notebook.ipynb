# %% [markdown]
# # Remove HTML Tags

# %%
text = """<div>
<h1>Title</h1>
<p>A long text........ </p>
<a href=""> a link </a>
</div>"""

# %%
import re
# as per recommendation from @freylis, compile once only
CLEANR = re.compile('<.*?>') 

def cleanhtml(raw_html):
  cleantext = re.sub(CLEANR, '', raw_html)
  return cleantext

# %%
cleanhtml(text)
# Out:
# '\nTitle\nA long text........ \n a link \n'

# %% [markdown]
# # Unicode Normalization

# %%
text = "I love 🍕!  Shall we book a 🚗 to gizza?"
Text = text.encode("utf-8")
print(Text)
# Out:
# b'I love \xf0\x9f\x8d\x95!  Shall we book a \xf0\x9f\x9a\x97 to gizza?'

# %% [markdown]
# # Spelling Correction

# %%
incorrect_spell = "I am bac! I pronise that I will not bresk the silence again!"

# %%
from textblob import TextBlob
textBlob = TextBlob(incorrect_spell)
textBlob.correct()
# Out:
# TextBlob("I am back! I promise that I will not break the silence again!")

# %% [markdown]
# # Tokenization

# %%
mytext = '''In the previous chapter, we saw examples of some common NLP 
applications that we might encounter in everyday life. If we were asked to 
build such an application, think about how we would approach doing so at our 
organization.'''

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
my_sentences = sent_tokenize(mytext)
print(my_sentences)
# Out:
# ['In the previous chapter, we saw examples of some common NLP \napplications that we might encounter in everyday life.', 'If we were asked to \nbuild such an application, think about how we would approach doing so at our \norganization.']

# %%
# words tokenization
for sentence in my_sentences:
   print(sentence,"\n")
   print(word_tokenize(sentence),"\n")
# Out:
# In the previous chapter, we saw examples of some common NLP
# applications that we might encounter in everyday life.
#
# ['In', 'the', 'previous', 'chapter', ',', 'we', 'saw', 'examples', 'of', 'some', 'common', 'NLP', 'applications', 'that', 'we', 'might', 'encounter', 'in', 'everyday', 'life', '.']
#
# If we were asked to
# build such an application, think about how we would approach doing so at our
# organization.
#
# ['If', 'we', 'were', 'asked', 'to', 'build', 'such', 'an', 'application', ',', 'think', 'about', 'how', 'we', 'would', 'approach', 'doing', 'so', 'at', 'our', 'organization', '.']
